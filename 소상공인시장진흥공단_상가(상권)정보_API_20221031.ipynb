# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

warnings.filterwarnings('ignore')

serviceKey='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

#대분류 조회

url ='https://apis.data.go.kr/B553077/api/open/sdsc2/largeUpjongList?serviceKey={}&type=json'.format(serviceKey)

#indsLclsCd #대분류 R #학문/교육
#indsMclsCd #중분류 R01 #학원 - 보습교습입시
#indsSclsCd #소분류 R01A01 #학원-입시

response = requests.get(url, verify=False)
#dict_data = xmltodict.parse(response.text)
#json_data = json.dumps(dict_data, ensure_ascii=False)
r_data = json.loads(response.text)

#Shape of passed values is (2, 4), indices imply (1, 4)
#data = pd.DataFrame(r_data['response']['body']['items']['item'])  이걸로 넣어주면 됨.

#If using all scalar values, you must pass an index 에러 문구가 뜰 경우, index=[0]
#data = pd.DataFrame(r_data['response']['body']['items']['item'], index=[0]) 이렇게 바꿔주면됨.


#columns=r_data['header']['columns']
raw_data = pd.DataFrame(r_data['body']['items'])
#raw_data

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

warnings.filterwarnings('ignore')

serviceKey='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

#중분류 조회

indsLclsCd = 'R'  #교육 (대분류코드)

url ='https://apis.data.go.kr/B553077/api/open/sdsc2/middleUpjongList?serviceKey={}&indsLclsCd={}'.format(serviceKey, indsLclsCd)

#indsLclsCd #대분류 R #학문/교육
#indsMclsCd #중분류 R01 #학원 - 보습교습입시
#indsSclsCd #소분류 R01A01 #학원-입시

response = requests.get(url, verify=False)
dict_data = xmltodict.parse(response.text)
json_data = json.dumps(dict_data, ensure_ascii=False)
r_data = json.loads(json_data)

#Shape of passed values is (2, 4), indices imply (1, 4)
#data = pd.DataFrame(r_data['response']['body']['items']['item'])  이걸로 넣어주면 됨.

#If using all scalar values, you must pass an index 에러 문구가 뜰 경우, index=[0]
#data = pd.DataFrame(r_data['response']['body']['items']['item'], index=[0]) 이렇게 바꿔주면됨.


#columns=r_data['header']['columns']
raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])

raw_data
# Out:
#    indsLclsCd indsLclsNm indsMclsCd          indsMclsNm      stdrDt
# 0           R  예술·스포츠·여가        R20              기타교육기관  2015-12-17
# 1           R  예술·스포츠·여가        R10             도서관/독서실  2015-12-17
# 2           R  예술·스포츠·여가        R91     스포츠 및 오락관련 서비스업  2015-12-17
# 3           R  예술·스포츠·여가        R14                 연구소  2015-12-17
# 4           R  예술·스포츠·여가        R08                유아교육  2015-12-17
# 5           R  예술·스포츠·여가        R90  창작, 예술 및 여가관련 서비스업  2015-12-17
# 6           R  예술·스포츠·여가        R12              특수교육기관  2015-12-17
# 7           R  예술·스포츠·여가        R11                  학교  2015-12-17
# 8           R  예술·스포츠·여가        R13              학문교육기타  2015-12-17
# 9           R  예술·스포츠·여가        R01           학원-보습교습입시  2015-12-17
# 10          R  예술·스포츠·여가        R04               학원-어학  2015-12-17
# 11          R  예술·스포츠·여가        R07           학원-예능취미체육  2015-12-17
# 12          R  예술·스포츠·여가        R05           학원-음악미술무용  2015-12-17
# ...

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

warnings.filterwarnings('ignore')

serviceKey='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

#소분류 조회

indsLclsCd = 'R'  #대분류
indsMclsCd = 'R11'  #중분류  R01  
url ='https://apis.data.go.kr/B553077/api/open/sdsc2/smallUpjongList?serviceKey={}&indsLclsCd={}&indsMclsCd={}'.format(serviceKey, indsLclsCd,indsMclsCd)

#R01 학원-보습교습입시
#R04 학원-어학

response = requests.get(url, verify=False)
dict_data = xmltodict.parse(response.text)
json_data = json.dumps(dict_data, ensure_ascii=False)
r_data = json.loads(json_data)

#Shape of passed values is (2, 4), indices imply (1, 4)
#data = pd.DataFrame(r_data['response']['body']['items']['item'])  이걸로 넣어주면 됨.

#If using all scalar values, you must pass an index 에러 문구가 뜰 경우, index=[0]
#data = pd.DataFrame(r_data['response']['body']['items']['item'], index=[0]) 이렇게 바꿔주면됨.


#columns=r_data['header']['columns']
raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])

raw_data
# Out:
#    indsLclsCd indsLclsNm indsMclsCd indsMclsNm indsSclsCd indsSclsNm  \
# 0           R      학문/교육        R11         학교     R11B08     고등공민학교
# 1           R      학문/교육        R11         학교     R11B07     고등기술학교
# 2           R      학문/교육        R11         학교     R11B03       고등학교
# 3           R      학문/교육        R11         학교     R11B12   기타고등교육기관
# 4           R      학문/교육        R11         학교     R11B09   기타중등교육기관
# 5           R      학문/교육        R11         학교     R11B04        대학교
# 6           R      학문/교육        R11         학교     R11B05        대학원
# 7           R      학문/교육        R11         학교     R11B10       신학대학
# 8           R      학문/교육        R11         학교     R11B06       전문대학
# 9           R      학문/교육        R11         학교     R11B02        중학교
# 10          R      학문/교육        R11         학교     R11B11     직업전문학교
# 11          R      학문/교육        R11         학교     R11B01       초등학교
#
#         stdrDt
# 0   2015-12-17
# 1   2015-12-17
# 2   2015-12-17
# ...

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

warnings.filterwarnings('ignore')

serviceKey='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

#입력 업종에 해당하는 업소목록 조회

divId = 'indsSclsCd' #소분류코드 #대분류 indsLclsCd #중분류 indsMclsCd
key = 'R13A01' 

pageNo = '1' #페이지 번호

numOfRows = '1000'

url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/storeListInUpjong?serviceKey={}&divId={}&key={}&pageNo={}&numOfRows={}'.format(serviceKey, divId, key, pageNo, numOfRows)

response = requests.get(url, verify=False)
dict_data = xmltodict.parse(response.text)
json_data = json.dumps(dict_data, ensure_ascii=False)
r_data = json.loads(json_data)

#Shape of passed values is (2, 4), indices imply (1, 4)
#data = pd.DataFrame(r_data['response']['body']['items']['item'])  이걸로 넣어주면 됨.

#If using all scalar values, you must pass an index 에러 문구가 뜰 경우, index=[0]
#data = pd.DataFrame(r_data['response']['body']['items']['item'], index=[0]) 이렇게 바꿔주면됨.


#columns=r_data['header']['columns']

try :
    raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])

except :
    raw_data = pd.DataFrame(r_data['response']['body']['items']['item'], index=0)
#raw_data

# %%
r_data['response']['body']['totalCount']
# Out:
# '2474'
