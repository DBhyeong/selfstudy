# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국문화정보원_예술지식 문학정보 서비스

#문학정보 디렉토리(목록) 조회

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

numOfRows=100

url = 'http://openapi.culture.go.kr/openapi/service/ArtKnwldgLtrtrService/getArtKnwldgLtrtr?serviceKey={}&numOfRows={}'.format(serviceKey, numOfRows)

response = requests.get(url, verify=False)

dict_data = xmltodict.parse(response.text) #xml을 json로 변환
json_data = json.dumps(dict_data, ensure_ascii=False)  #한글이 깨지면 ensure_ascii 코드를 False로 하면됨.

r_data = json.loads(json_data)

r_data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'creatdate': '2004-10-20',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '1',
#       'seq': '7810',
#       'subject': '식민지시대 비평사 Ⅰ- 개요'},
#      {'creatdate': '2004-10-20',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '2',
#       'seq': '7811',
#       'subject': '식민지시대 비평사 Ⅱ- 근대적 비평의 모색'},
#      {'creatdate': '2004-10-20',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '3',
#       'seq': '7812',
#       'subject': '식민지시대 비평사 Ⅲ- 근대적 비평의 확립'},
#      {'creatdate': '2004-10-20',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '4',
#       'seq': '7813',
#       'subject': '식민지시대 비평사 Ⅳ'},
#      {'creatdate': '2004-10-20',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '5',
#       'seq': '7814',
#       'subject': '초기 문단과 동인지 Ⅰ- 개관'},
#      {'creatdate': '2004-10-20',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '6',
#       'seq': '7815',
#       'subject': '초기 문단과 동인지 Ⅱ- 1920년대'},
#      {'creatdate': '2004-10-20',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '7',
#       'seq': '7816',
#       'subject': '초기 문단과 동인지 Ⅲ- 1930년대~해방'},
#      {'creatdate': '2004-10-20',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '8',
#       'seq': '7874',
#       'subject': '문학관 기행'},
#      {'creatdate': '2005-10-24',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '9',
#       'seq': '8254',
#       'subject': '각색의 이해'},
#      {'creatdate': '2005-10-24',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '10',
#       'seq': '8255',
#       'subject': '비평문학사 : 해방~1950년대'},
#      {'creatdate': '2005-10-24',
#       'ctgry3': 'H000',
#       'ctgry3Nm': '문학',
#       'rnum': '11',
#       'seq': '8256',
#       'subject': '우리 문학사와 분단문학'},
#      {'creatdate': '2004-10-11',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H131',
#       'ctgry3Nm': '신문학의 등장~1910년대',
#       'rnum': '12',
#       'seq': '7385',
#       'subject': '해에게서 소년에게'},
#      {'creatdate': '2004-10-14',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H131',
#       'ctgry3Nm': '신문학의 등장~1910년대',
#       'rnum': '13',
#       'seq': '7473',
#       'subject': '봄은 간다'},
#      {'creatdate': '2004-10-14',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H131',
#       'ctgry3Nm': '신문학의 등장~1910년대',
#       'rnum': '14',
#       'seq': '7476',
#       'subject': '불놀이'},
#      {'creatdate': '2004-10-17',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '15',
#       'seq': '7537',
#       'subject': '병든 서울'},
#      {'creatdate': '2004-10-17',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '16',
#       'seq': '7549',
#       'subject': '오랑캐꽃'},
#      {'creatdate': '2004-10-17',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '17',
#       'seq': '7555',
#       'subject': '자화상'},
#      {'creatdate': '2004-10-17',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '18',
#       'seq': '7565',
#       'subject': '참회록'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '19',
#       'seq': '8196',
#       'subject': '나그네'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '20',
#       'seq': '8198',
#       'subject': '나의 거리'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '21',
#       'seq': '8206',
#       'subject': '전라도길'},
#      {'creatdate': '2006-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '22',
#       'seq': '8762',
#       'subject': '동절'},
#      {'creatdate': '2006-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '23',
#       'seq': '8763',
#       'subject': '뒷골목이 트일 때까지'},
#      {'creatdate': '2006-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '24',
#       'seq': '8764',
#       'subject': '상치쌈'},
#      {'creatdate': '2006-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '25',
#       'seq': '8765',
#       'subject': '어머니'},
#      {'creatdate': '2006-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H431',
#       'ctgry3Nm': '1940년대',
#       'rnum': '26',
#       'seq': '8766',
#       'subject': '어머니'},
#      {'creatdate': '2004-10-19',
#       'ctgry2': 'H041',
#       'ctgry2Nm': '소설',
#       'ctgry3': 'H441',
#       'ctgry3Nm': '1940년대',
#       'rnum': '27',
#       'seq': '7705',
#       'subject': '장삼이사'},
#      {'creatdate': '2004-10-20',
#       'ctgry2': 'H041',
#       'ctgry2Nm': '소설',
#       'ctgry3': 'H441',
#       'ctgry3Nm': '1940년대',
#       'rnum': '28',
#       'seq': '7809',
#       'subject': '후처기'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H041',
#       'ctgry2Nm': '소설',
#       'ctgry3': 'H441',
#       'ctgry3Nm': '1940년대',
#       'rnum': '29',
#       'seq': '8222',
#       'subject': '균열'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H041',
#       'ctgry2Nm': '소설',
#       'ctgry3': 'H441',
#       'ctgry3Nm': '1940년대',
#       'rnum': '30',
#       'seq': '8223',
#       'subject': '도정'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H041',
#       'ctgry2Nm': '소설',
#       'ctgry3': 'H441',
#       'ctgry3Nm': '1940년대',
#       'rnum': '31',
#       'seq': '8243',
#       'subject': '역마'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H041',
#       'ctgry2Nm': '소설',
#       'ctgry3': 'H441',
#       'ctgry3Nm': '1940년대',
#       'rnum': '32',
#       'seq': '8249',
#       'subject': '잔등'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H041',
#       'ctgry2Nm': '소설',
#       'ctgry3': 'H441',
#       'ctgry3Nm': '1940년대',
#       'rnum': '33',
#       'seq': '8251',
#       'subject': '풍류잡히는 마을'},
#      {'creatdate': '2006-10-22',
#       'ctgry2': 'H041',
#       'ctgry2Nm': '소설',
#       'ctgry3': 'H441',
#       'ctgry3Nm': '1940년대',
#       'rnum': '34',
#       'seq': '8778',
#       'subject': '창'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H251',
#       'ctgry3Nm': '향가',
#       'rnum': '35',
#       'seq': '8095',
#       'subject': '모죽지랑가(慕竹旨郞歌)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H251',
#       'ctgry3Nm': '향가',
#       'rnum': '36',
#       'seq': '8096',
#       'subject': '서동요(薯童謠)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H251',
#       'ctgry3Nm': '향가',
#       'rnum': '37',
#       'seq': '8097',
#       'subject': '제망매가(祭亡妹歌)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H251',
#       'ctgry3Nm': '향가',
#       'rnum': '38',
#       'seq': '8098',
#       'subject': '찬기파랑가(讚耆婆郞歌)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H251',
#       'ctgry3Nm': '향가',
#       'rnum': '39',
#       'seq': '8099',
#       'subject': '처용가(處容歌)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H251',
#       'ctgry3Nm': '향가',
#       'rnum': '40',
#       'seq': '8100',
#       'subject': '헌화가(獻花歌)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H451',
#       'ctgry3Nm': '경기체가',
#       'rnum': '41',
#       'seq': '8113',
#       'subject': '관동별곡(關東別曲)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H451',
#       'ctgry3Nm': '경기체가',
#       'rnum': '42',
#       'seq': '8114',
#       'subject': '한림별곡(翰林別曲)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H651',
#       'ctgry3Nm': '시조',
#       'rnum': '43',
#       'seq': '8117',
#       'subject': '강호사시가(江湖四時歌)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H651',
#       'ctgry3Nm': '시조',
#       'rnum': '44',
#       'seq': '8118',
#       'subject': '고산구곡가(高山九曲歌)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H651',
#       'ctgry3Nm': '시조',
#       'rnum': '45',
#       'seq': '8119',
#       'subject': '도산십이곡(陶山十二曲)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H651',
#       'ctgry3Nm': '시조',
#       'rnum': '46',
#       'seq': '8120',
#       'subject': '어부사시사(漁父四時詞)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H651',
#       'ctgry3Nm': '시조',
#       'rnum': '47',
#       'seq': '8121',
#       'subject': '개야미 불개야미…'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H851',
#       'ctgry3Nm': '한시',
#       'rnum': '48',
#       'seq': '8138',
#       'subject': '동명왕편(東明王篇)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H851',
#       'ctgry3Nm': '한시',
#       'rnum': '49',
#       'seq': '8139',
#       'subject': '소악부(小樂府)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H851',
#       'ctgry3Nm': '한시',
#       'rnum': '50',
#       'seq': '8140',
#       'subject': '송인(送人)'},
#      {'creatdate': '2005-10-20',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H851',
#       'ctgry3Nm': '한시',
#       'rnum': '51',
#       'seq': '8141',
#       'subject': '여수장우중문시(與隋將于仲文詩)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H851',
#       'ctgry3Nm': '한시',
#       'rnum': '52',
#       'seq': '8142',
#       'subject': '추야우중(秋夜雨中)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H051',
#       'ctgry2Nm': '고전시가',
#       'ctgry3': 'H851',
#       'ctgry3Nm': '한시',
#       'rnum': '53',
#       'seq': '8143',
#       'subject': '탐진촌요(耽津村謠)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H461',
#       'ctgry3Nm': '한문소설',
#       'rnum': '54',
#       'seq': '8157',
#       'subject': '양반전(兩班傳)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H461',
#       'ctgry3Nm': '한문소설',
#       'rnum': '55',
#       'seq': '8158',
#       'subject': '원생몽유록(元生夢遊錄)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H461',
#       'ctgry3Nm': '한문소설',
#       'rnum': '56',
#       'seq': '8159',
#       'subject': '이생규장전(李生窺牆傳)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H461',
#       'ctgry3Nm': '한문소설',
#       'rnum': '57',
#       'seq': '8160',
#       'subject': '허생전(許生傳)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H561',
#       'ctgry3Nm': '국문소설',
#       'rnum': '58',
#       'seq': '8161',
#       'subject': '구운몽(九雲夢)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H561',
#       'ctgry3Nm': '국문소설',
#       'rnum': '59',
#       'seq': '8162',
#       'subject': '박씨전'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H561',
#       'ctgry3Nm': '국문소설',
#       'rnum': '60',
#       'seq': '8163',
#       'subject': '심청전'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H561',
#       'ctgry3Nm': '국문소설',
#       'rnum': '61',
#       'seq': '8164',
#       'subject': '장끼전'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H561',
#       'ctgry3Nm': '국문소설',
#       'rnum': '62',
#       'seq': '8165',
#       'subject': '춘향전'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H561',
#       'ctgry3Nm': '국문소설',
#       'rnum': '63',
#       'seq': '8166',
#       'subject': '홍길동전'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H561',
#       'ctgry3Nm': '국문소설',
#       'rnum': '64',
#       'seq': '8167',
#       'subject': '흥부전'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H661',
#       'ctgry3Nm': '고전수필',
#       'rnum': '65',
#       'seq': '8168',
#       'subject': '어우야담(於于野譚)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H661',
#       'ctgry3Nm': '고전수필',
#       'rnum': '66',
#       'seq': '8169',
#       'subject': '열하일기(熱河日記)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H661',
#       'ctgry3Nm': '고전수필',
#       'rnum': '67',
#       'seq': '8170',
#       'subject': '조침문(弔針文)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H061',
#       'ctgry2Nm': '고전산문',
#       'ctgry3': 'H661',
#       'ctgry3Nm': '고전수필',
#       'rnum': '68',
#       'seq': '8171',
#       'subject': '한중록(閑中錄)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H171',
#       'ctgry3Nm': '고려시대',
#       'rnum': '69',
#       'seq': '8172',
#       'subject': '보한집(補閑集)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H171',
#       'ctgry3Nm': '고려시대',
#       'rnum': '70',
#       'seq': '8173',
#       'subject': '삼국사기(三國史記)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H171',
#       'ctgry3Nm': '고려시대',
#       'rnum': '71',
#       'seq': '8174',
#       'subject': '삼국유사(三國遺事)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H171',
#       'ctgry3Nm': '고려시대',
#       'rnum': '72',
#       'seq': '8176',
#       'subject': '역옹패설(&#27359;翁稗說)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H171',
#       'ctgry3Nm': '고려시대',
#       'rnum': '73',
#       'seq': '8177',
#       'subject': '파한집(破閑集)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '74',
#       'seq': '8178',
#       'subject': '가곡원류(歌曲源流)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '75',
#       'seq': '8179',
#       'subject': '고려사악지(高麗史樂志)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '76',
#       'seq': '8180',
#       'subject': '대동운부군옥(大東韻府群玉)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '77',
#       'seq': '8181',
#       'subject': '동문선(東文選)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '78',
#       'seq': '8183',
#       'subject': '동인시화(東人詩話)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '79',
#       'seq': '8184',
#       'subject': '시용향악보(時用鄕樂譜)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '80',
#       'seq': '8186',
#       'subject': '악장가사(樂章歌詞)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '81',
#       'seq': '8187',
#       'subject': '악학궤범(樂學軌範)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '82',
#       'seq': '8189',
#       'subject': '용재총화(&#24949;齋叢話)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '83',
#       'seq': '8190',
#       'subject': '청구영언(靑丘永言)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H071',
#       'ctgry2Nm': '국문학문헌',
#       'ctgry3': 'H271',
#       'ctgry3Nm': '조선시대',
#       'rnum': '84',
#       'seq': '8192',
#       'subject': '해동가요(海東歌謠)'},
#      {'creatdate': '2005-10-19',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '85',
#       'seq': '8038',
#       'subject': '울음이 타는 가을강'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '86',
#       'seq': '8195',
#       'subject': '꽃'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '87',
#       'seq': '8197',
#       'subject': '나비와 광장'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '88',
#       'seq': '8199',
#       'subject': '낙화'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '89',
#       'seq': '8200',
#       'subject': '눈물'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '90',
#       'seq': '8201',
#       'subject': '동(冬)'},
#      {'creatdate': '2005-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '91',
#       'seq': '8202',
#       'subject': '목마와 숙녀'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '92',
#       'seq': '8203',
#       'subject': '새 1'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '93',
#       'seq': '8210',
#       'subject': '주점'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '94',
#       'seq': '8212',
#       'subject': '청자수병'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '95',
#       'seq': '8214',
#       'subject': '폭포'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '96',
#       'seq': '8215',
#       'subject': '풀잎'},
#      {'creatdate': '2005-10-24',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '97',
#       'seq': '8217',
#       'subject': '휴전선'},
#      {'creatdate': '2006-09-29',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '98',
#       'seq': '8562',
#       'subject': '바라춤'},
#      {'creatdate': '2006-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '99',
#       'seq': '8767',
#       'subject': '램프의 시 5'},
#      {'creatdate': '2006-10-21',
#       'ctgry2': 'H031',
#       'ctgry2Nm': '시',
#       'ctgry3': 'H531',
#       'ctgry3Nm': '1950년대',
#       'rnum': '100',
#       'seq': '8768',
#       'subject': '봄비'}]},
#    'numOfRows': '100',
#    'pageNo': '1',
#    'totalCount': '400'}}}

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국문화정보원_예술지식 문학정보 서비스

#문학정보 작품상세정보 조회

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'
seq = '8768'

url = 'http://openapi.culture.go.kr/openapi/service/ArtKnwldgLtrtrService/getArtKnwldgLtrtrDetail?serviceKey={}&seq={}'.format(serviceKey, seq)

response = requests.get(url, verify=False)

dict_data = xmltodict.parse(response.text) #xml을 json로 변환
json_data = json.dumps(dict_data, ensure_ascii=False)  #한글이 깨지면 ensure_ascii 코드를 False로 하면됨.

r_data = json.loads(json_data)

r_data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'contents': '봄비', 'num': '1', 'subject': '제목'},
#      {'contents': '봄비\r\n\r\n\r\n이 비 그치면\r\n내 마음 강나루 긴 언덕에\r\n서러운 풀빛이 짙어오것다.\r\n\r\n푸르른 보리밭길\r\n맑은 하늘에\r\n종달새만 무에라고 지껄이것다.\r\n\r\n이 비 그치면\r\n시새워 벙글어질 고운 꽃밭 속\r\n처녀애들 짝하여 새로이 서고\r\n\r\n임 앞에 타오르는 향연같이\r\n땅에선 또 아지랑이 타오르것다.\r\n\r\n- <봄비>, 이수복, 현대문학사, 1968',
#       'num': '2'},
#      {'contents': '이수복(李壽福, 1924~1986)\r\n전남 함평군 출생. 목포 문태중학을 거쳐 광주 조선대학 국문과 졸업. 1954년 <문예(文藝)>에 <동백(冬柏)꽃>, 1955년 <현대문학>에 <실솔(&#34763;&#34752;)>, <봄비>가 추천됨으로써 문단에 등장했다. 고유정서(固有情緖)의 밝고 건전한 측면을 추구하는 그의 대표작으로 위의 작품 외에 <모란송(頌)>, <하 아까움이여>, <일지(日誌)>, <잎무늬>, <햇살> 등이 있다. 1957년 제3회 현대문학 신인문학상을 수상했으며, 전라남도 문화상을 받았다. 조용한 눌언(訥言)의 시인으로 조선대학에 출강하기도 했으며, 광주 수피아(須彼亞)여고, 광주일고, 순천고교 등에서 재직하였다.',
#       'num': '3',
#       'subject': '저자'},
#      {'contents': '이수복 형이 그 섬세한 감각적 서정을 우리들에게 보여주기 시작한 것은 <문예> 때부터였다. 그러니까 이미 20년 가까운 세월이 된다. 그동안 그는 많은 작품을 발표했고, 그의 작품은 발표될 때마다 항상 특별한 주목을 받아왔으나 그는 늘 숨어사는 별처럼 겸손하기만 했다. 그의 처녀시집인 이 시집 속에 그 많은 수작들 중에서도 겨우 34편만을 골랐다는 이 자체도 이 시인의 겸손을 말해주는 것 같다.\r\n\r\n새댁은 닦아놓고 안방에 숨고\r\n낮달마냥 없는듯기\r\n안방에 숨고\r\n알길없어 무장좋은\r\n모란꽃 그늘······\r\n어떻든 빈 하늘을 고이 다루네.\r\n\r\n이것은 이 시집 속에서 내가 즐겨 읽던 한 구절이다. 나는 이런 구절에 대할 때마다 ‘안방’에 숨은 새댁 같은 이 시인을 연상한다. 섬세한 정신의 능력에 나의 우둔한 감성은 언제나 놀라고 만다. 그의 이와 같은 조용한 겸손이 ‘빈 하늘’만이 아니라 이 세상 온갖 것을 누구보다도 가장 잘 고이 다룰 것을 생각하면 더욱 놀라운 일이 아닐 수 없다.\r\n숨은 별빛과 같은 이 시집이 누구나의 버릴 수 없는 마음의 빛이 되기를 바란다.\r\n ‘서’, 조연현, <봄비>, 현대문학사, 1968</div>',
#       'num': '4',
#       'subject': '리뷰'},
#      {'contents': '1954년 3월호 <문예>지에 졸작 <동백꽃>이 미당선생의 천(薦)을 입은 이래 오늘까지 발표해온 작품들 중에서 아쉽게 34편을 골라 시집을 엮고, 책제(冊題)를 <봄비>라 붙인다.\r\n나는 이 34편을 참으로 아쉽게 골랐다. 이들 중 나를 격려해주기 위해서 미당선생께서 추천해주신 세 편(<동백꽃>, <실솔(&#34763;&#34752;)>, <봄비>)의 시작(詩作) 말고는 나머지 어느 것에 대해서도 자신을 가질 수가 없어 불안한 것뿐이다.\r\n차림새에 있어 1에서 7까지로 나누어 차려놓기는 했지만 여기에는 무슨 그럴듯한 까닭이 있어서라기보다는 내 시들이 변화가 없이 너무 단조롭기만 한 것이 이렇게라도 해서 위장시켜볼까 한 심산에서 그래 본 것이다. 시다운 시를 한 편도 못 가지면서 시집을 엮고 있는 모순되고도 불안한 마음이 이 같은 잔꾀를 쓰고 숨자는 것일 게다. (……)\r\n ‘후기’, 이수복, <봄비>, 현대문학사, 1968</div>',
#       'num': '5',
#       'subject': '작가의 말'},
#      {'contents': '<한국현대문학대사전>, 권영민 편, 서울대학교출판부, 2004\r\n<한국문학대사전>, 권영민, 고려출판사, 1992\r\n<봄비>, 이수복, 현대문학사, 1968',
#       'num': '6',
#       'subject': '관련도서'}]}}}}
