# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#학교

warnings.filterwarnings('ignore')

key ='f499cf2525b243dabaa45097304a2f86'

ATPT_OFCDC_SC_CODE = 'B10'  #코드

#B10	서울특별시교육청
#C10	부산광역시교육청
#D10	대구광역시교육청
#E10	인천광역시교육청
#F10	광주광역시교육청
#G10	대전광역시교육청
#H10	울산광역시교육청
#I10	세종특별자치시교육청
#J10	경기도교육청
#K10	강원도교육청
#M10	충청북도교육청
#N10	충청남도교육청
#P10	전라북도교육청
#Q10	전라남도교육청
#R10	경상북도교육청
#S10	경상남도교육청
#T10	제주특별자치도교육청

pIndex = 1 #순서

url = 'https://open.neis.go.kr/hub/schoolInfo?KEY={}&Type=json&pIndex={}&ATPT_OFCDC_SC_CODE={}'.format(key,pIndex, ATPT_OFCDC_SC_CODE)

response = requests.get(url, verify=False)
#HTTPSConnectionPool(host='www.work.go.kr', port=443): Max retries exceeded with url 
# 오류 발견시 requests.get(url, verify=False) 로 넣어주면됨. 

#response.text

#dict_data = xmltodict.parse(response.text) #xml을 json로 변환
#json_data = json.dumps(dict_data, ensure_ascii=False)  #한글이 깨지면 ensure_ascii 코드를 False로 하면됨.


#dict_data = xmltodict.parse(response.text)
#json_data = json.dumps(dict_data, ensure_ascii=False)
#r_data = json.loads(json_data)

r_data = json.loads(response.text)  #json 변환
#r_data
data = pd.DataFrame(r_data['schoolInfo'][1]['row'])  #데이터프레임으로 보자
#data #완료

#r_data

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#학원 & 교습소

warnings.filterwarnings('ignore')

key ='f499cf2525b243dabaa45097304a2f86'

ATPT_OFCDC_SC_CODE = 'B10'  #코드

#B10	서울특별시교육청
#C10	부산광역시교육청
#D10	대구광역시교육청
#E10	인천광역시교육청
#F10	광주광역시교육청
#G10	대전광역시교육청
#H10	울산광역시교육청
#I10	세종특별자치시교육청
#J10	경기도교육청
#K10	강원도교육청
#M10	충청북도교육청
#N10	충청남도교육청
#P10	전라북도교육청
#Q10	전라남도교육청
#R10	경상북도교육청
#S10	경상남도교육청
#T10	제주특별자치도교육청

pIndex = 1

url = 'https://open.neis.go.kr/hub/acaInsTiInfo?KEY={}&Type=json&pIndex={}&ATPT_OFCDC_SC_CODE={}'.format(key,pIndex, ATPT_OFCDC_SC_CODE)

response = requests.get(url, verify=False)
#HTTPSConnectionPool(host='www.work.go.kr', port=443): Max retries exceeded with url 
# 오류 발견시 requests.get(url, verify=False) 로 넣어주면됨. 

#response.text

#dict_data = xmltodict.parse(response.text) #xml을 json로 변환
#json_data = json.dumps(dict_data, ensure_ascii=False)  #한글이 깨지면 ensure_ascii 코드를 False로 하면됨.


#dict_data = xmltodict.parse(response.text)
#json_data = json.dumps(dict_data, ensure_ascii=False)
#r_data = json.loads(json_data)

r_data = json.loads(response.text)  #json 변환
data = pd.DataFrame(r_data['acaInsTiInfo'][1]['row'])  #데이터프레임으로 보자
data.head() #완료

#r_data
# Out:
#   ATPT_OFCDC_SC_CODE ATPT_OFCDC_SC_NM ADMST_ZONE_NM ACA_INSTI_SC_NM  \
# 0                B10         서울특별시교육청           강남구             교습소
# 1                B10         서울특별시교육청           강남구             교습소
# 2                B10         서울특별시교육청           강남구             교습소
# 3                B10         서울특별시교육청           강남구             교습소
# 4                B10         서울특별시교육청           강남구             교습소
#
#     ACA_ASNUM                 ACA_NM ESTBL_YMD   REG_YMD REG_STTUS_NM  \
# 0  3000037367                1%국어교습소  20200819  20200819           개원
# 1  3000039509         123에듀진학상담지도교습소  20210723  20210723           개원
# 2  3000040501  301아카데미(Academy)영어교습소  20211228  20211228           개원
# 3  3000017743           3에스잉글리쉬영어교습소  20130715  20130715           개원
# 4  3000024877          9087스튜디오미술교습소  20151208  20151208           개원
#
#   CAA_BEGIN_YMD  ... LE_ORD_NM  LE_CRSE_LIST_NM  LE_CRSE_NM PSNBY_THCC_CNTNT  \
# 0          None  ...      보통교과             None          보습             None
# 1          None  ...      진학지도             None      진학상담지도             None
# 2          None  ...      보통교과             None          보습             None
# 3          None  ...      보통교과               영어          보습             None
# 4          None  ...     예능(중)              드로잉          미술             None
#
#   THCC_OTHBC_YN BRHS_ACA_YN FA_RDNZC              FA_RDNMA  \
# 0             Y           N    06207     서울특별시 강남구 도곡로 405
# 1             Y           N    06209   서울특별시 강남구 삼성로63길 19
# 2             Y           N    06329    서울특별시 강남구 개포로82길 7
# 3          None           N   135888    서울특별시 강남구 압구정로 114
# 4             Y           N    06755  서울특별시 서초구 바우뫼로20길 25
#
#                 FA_RDNDA  LOAD_DTM
# 0           / 309호 (대치동)  20221009
# 1           / 4층일부 (대치동)  20221009
# 2  / 3층 301호 (개포동/ 삼성빌딩)  20221009
# 3      / 302호 (신사동/신사빌딩)  20221009
# 4     / 201호 (양재동/ 서두빌딩)  20221009
#
# [5 rows x 24 columns]
