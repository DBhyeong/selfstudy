# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다
import time

warnings.filterwarnings('ignore')

serviceKey='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

#입력 업종에 해당하는 업소목록 조회

divId = 'indsSclsCd' #소분류코드 #대분류 indsLclsCd #중분류 indsMclsCd
key = 'R04A01' 

pageNo = 1 #페이지 번호

numOfRows = 1000

for i in range(1, 22) :
    try :
        pageNo = str(i)    
        url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/storeListInUpjong?serviceKey={}&divId={}&key={}&pageNo={}&numOfRows={}'.format(serviceKey, divId, key, pageNo, numOfRows)

        response = requests.get(url, verify=False)
        dict_data = xmltodict.parse(response.text)
        json_data = json.dumps(dict_data, ensure_ascii=False)
        r_data = json.loads(json_data)

        #Shape of passed values is (2, 4), indices imply (1, 4)
        #data = pd.DataFrame(r_data['response']['body']['items']['item'])  이걸로 넣어주면 됨.

        #If using all scalar values, you must pass an index 에러 문구가 뜰 경우, index=[0]
        #data = pd.DataFrame(r_data['response']['body']['items']['item'], index=[0]) 이렇게 바꿔주면됨.


        #columns=r_data['header']['columns']


        raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])

        df_2 = df_2.append(raw_data, ignore_index=False)

        time.sleep(1) #1초

        print(str(pageNo) + "의 데이터를 처리하였습니다.")
    except :
        pass

df_2.to_csv('C:/Users/user/Desktop/에이블스튜디오/시장조사/'+str(key) +'.csv', encoding='utf-8-sig') #엑셀파일화 

print("최종완료")
# Out:
# 1의 데이터를 처리하였습니다.
# 2의 데이터를 처리하였습니다.
# 3의 데이터를 처리하였습니다.
# 4의 데이터를 처리하였습니다.
# 5의 데이터를 처리하였습니다.
# 6의 데이터를 처리하였습니다.
# 7의 데이터를 처리하였습니다.
# 8의 데이터를 처리하였습니다.
# 9의 데이터를 처리하였습니다.
# 10의 데이터를 처리하였습니다.
# 11의 데이터를 처리하였습니다.
# 12의 데이터를 처리하였습니다.
# 13의 데이터를 처리하였습니다.
# 14의 데이터를 처리하였습니다.
# 15의 데이터를 처리하였습니다.
# 16의 데이터를 처리하였습니다.
# 17의 데이터를 처리하였습니다.
# 18의 데이터를 처리하였습니다.
# 19의 데이터를 처리하였습니다.
# 20의 데이터를 처리하였습니다.
# 21의 데이터를 처리하였습니다.
# 최종완료

# %%
##### 컬럼 이외 모든 행 지우기

df_2 = df.iloc[:1] #행 1개만 남겨두기
df_2 = df_2.drop(index=0, axis=1)  #1개 행 다 지우기
df_2  #완료
# Out:
# Empty DataFrame
# Columns: [bizesId, bizesNm, brchNm, indsLclsCd, indsLclsNm, indsMclsCd, indsMclsNm, indsSclsCd, indsSclsNm, ksicCd, ksicNm, ctprvnCd, ctprvnNm, signguCd, signguNm, adongCd, adongNm, ldongCd, ldongNm, lnoCd, plotSctCd, plotSctNm, lnoMnno, lnoSlno, lnoAdr, rdnmCd, rdnm, bldMnno, bldSlno, bldMngNo, bldNm, rdnmAdr, oldZipcd, newZipcd, dongNo, flrNo, hoNo, lon, lat]
# Index: []
#
# [0 rows x 39 columns]
