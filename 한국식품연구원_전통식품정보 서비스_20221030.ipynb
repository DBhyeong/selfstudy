# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국식품연구원_전통식품정보 서비스

#대표식품 목록 및 분류

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

url = 'http://apis.data.go.kr/B551553/TradFoodInfoService/getFoodCateogryList?serviceKey={}&type=json'.format(serviceKey)

response = requests.get(url, verify=False)

r_data = json.loads(response.text)

raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])
raw_data
# Out:
#    foodCd  foodNm foodKindNm largeClsNm middleClsNm smallClsNm tradFoodCnt
# 0  100003    가루전병       복합식품         부식         구이류          전           1
# 1  100004    가물치국       복합식품         부식          국류        토장국           3
# 2  100005    가물치회       복합식품         부식          회류         생회           5
# 3  100009  가시연꽃열매       단일식품        조미식         양념류        양념류           1
# 4  100010    가시연밥       복합식품         주식          밥류         기타           9
# 5  100016   가오리어채       복합식품         부식          회류         기타           1
# 6  100017     가이주       복합식품         주류          기타         기타           1
# 7  100018     가자미       단일식품         기타          기타         기타           1
# 8  100019    가자미국       복합식품         부식          국류         기타           1
# 9  100020    가자미젓       복합식품         부식         젓갈류        발효젓           2

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국식품연구원_전통식품정보 서비스

#대표식품별 전통식품 목록

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

url = 'http://apis.data.go.kr/B551553/TradFoodInfoService/getTradFoodList?serviceKey={}&type=json'.format(serviceKey)

response = requests.get(url, verify=False)

r_data = json.loads(response.text)

raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])
raw_data
# Out:
#    foodCd foodNm tradFoodCd   tradFoodNm tradFoodNmOri tradFoodNmKr  \
# 0  100957   당귀뿌리     103726     당귀뿌리 저장법        當敀根収藏法       당귀근수장법
# 1  100999    대두주     183504   대두주 만드는 방법          大豆酒方         대두주방
# 2  100999    대두주     181366          대두주            大豆           대두
# 3  101107   도미찌개     105874         도미찌개      되미(道味)찌개           도미
# 4  102414   생강단자     109411         생강단자          생간단자         생강단자
# 5  102414   생강단자     105202         생강단자  생단자(生 團餈 생면)         생막단자
# 6  101434  만청자기름     104296  만청자기름 만드는 법         蔓菁子油法        만청자유법
# 7  102747    소흥주     010449          소흥주           紹興酒          소흥주
# 8  101614     무국     183133           무국           蘿蔔羹          나복갱
# 9  101622     무떡     107446           무떡           무우           무떡
#
#   tradFoodNmDiff tradFoodNmEn tradFoodNmEnTrans       docNm  \
# 0                                                      산림경제
# 1                                                 임원십육지-보양지
# 2                                                      식료찬요
# 3                                                      우리음식
# 4                                                     조선요리법
# 5                                                조선무쌍신식요리제법
# 6                                                      박해통고
# 7                                                      부연일기
# 8                                                  거가필용사류전집
# 9                                                      시의전서
#
#                                             transTxt dbYear
# 0  10월에 수확한 송이버섯은 토굴을 만들어 보관하면서 소금에 절여 두었다가 봄에 꺼내...   2012
# 1  《또 다른 방법 》：중풍으로 입을 벌릴 수 없고 몸이 뒤틀리고 말을 못하는 것을 치...   2016
# 2  산후에 중풍이 매우 심하거나[中風困篤] 혹은 등이 뻣뻣하고[背强] 입을 벌리지 못하...   2015
# 3  민어찌개와 같은 방법으로 한다. 생선의 뼈가 허름한 것이 아니면 표고나 느타리버섯을...   2012
# 4  재료\n찹쌀가루, 생강, 석이버섯, 대추\n\n찹쌀가루에 생강을 섞어 은행 떡 같이...   2012
# 5  생강의 껍질을 벗기고 오랫동안 물에 삶아서 쓰고 매운 맛을 뺀다. 잘게 다지고 계핏...   2012
# 6                            기름을 내는 법은 앞에 자소자유법과 같다.   2012
# 7  이른바 소흥주(紹興酒)라는 것은 소주가 아니라 빚어서 만드는 것인데, 엷은 황색이었...   2011
# 8  양고기 1근, 무 반 근을 깍둑썰기 하여 물 1~2사발, 파 3줄기, 천초 30알을...   2016
# 9  무를 얇게 저며 소금물에 담갔다가 체에 건져서 쌀가루에 버무린 후 가루를 모두 털어...   2012

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국식품연구원_전통식품정보 서비스

#전통식품 상세정보

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

tradFoodCd = '103726' #전통식품코드

url = 'http://apis.data.go.kr/B551553/TradFoodInfoService/getTradFoodInfo?serviceKey={}&type=json&tradFoodCd={}'.format(serviceKey, tradFoodCd)

response = requests.get(url, verify=False)

r_data = json.loads(response.text)

raw_data = pd.DataFrame(r_data['response']['body']['item'])
raw_data
# Out:
#            foodCd foodNm tradFoodCd docNm docOri    author    year page  \
# item       100957   당귀뿌리     103726  산림경제   山林經濟  홍만선(洪萬選)  1700년대
# numOfRows  100957   당귀뿌리     103726  산림경제   山林經濟  홍만선(洪萬選)  1700년대
# pageNo     100957   당귀뿌리     103726  산림경제   山林經濟  홍만선(洪萬選)  1700년대
# totCnt     100957   당귀뿌리     103726  산림경제   山林經濟  홍만선(洪萬選)  1700년대
#
#                   ipc ktkrc  ... tradFoodNmOri tradFoodNmKr tradFoodNmDiff  \
# item       A23B 7/153        ...        當敀根収藏法       당귀근수장법
# numOfRows  A23B 7/153        ...        當敀根収藏法       당귀근수장법
# pageNo     A23B 7/153        ...        當敀根収藏法       당귀근수장법
# totCnt     A23B 7/153        ...        當敀根収藏法       당귀근수장법
#
#           tradFoodNmEn tradFoodNmEnTrans  \
# item
# numOfRows
# pageNo
# totCnt
#
#                                                  oriTxt  \
# item       十月採根作大窖種於其中，時松茸加塩令極醎，至春取出退塩於米泔水用之，又初冬投淡葅中甚佳。
# numOfRows  十月採根作大窖種於其中，時松茸加塩令極醎，至春取出退塩於米泔水用之，又初冬投淡葅中甚佳。
# pageNo     十月採根作大窖種於其中，時松茸加塩令極醎，至春取出退塩於米泔水用之，又初冬投淡葅中甚佳。
# totCnt     十月採根作大窖種於其中，時松茸加塩令極醎，至春取出退塩於米泔水用之，又初冬投淡葅中甚佳。
#
#                                                     transTxt  \
# item       10월에 수확한 송이버섯은 토굴을 만들어 보관하면서 소금에 절여 두었다가 봄에 꺼내...
# numOfRows  10월에 수확한 송이버섯은 토굴을 만들어 보관하면서 소금에 절여 두었다가 봄에 꺼내...
# pageNo     10월에 수확한 송이버섯은 토굴을 만들어 보관하면서 소금에 절여 두었다가 봄에 꺼내...
# totCnt     10월에 수확한 송이버섯은 토굴을 만들어 보관하면서 소금에 절여 두었다가 봄에 꺼내...
#
#                                                       recipe cookingTool  \
# item       1) 10월에 수확한 송이버섯은 토굴을 만들어 보관하면서 소금에 절여둔다.\n2) ...
# numOfRows  1) 10월에 수확한 송이버섯은 토굴을 만들어 보관하면서 소금에 절여둔다.\n2) ...
# pageNo     1) 10월에 수확한 송이버섯은 토굴을 만들어 보관하면서 소금에 절여둔다.\n2) ...
# totCnt     1) 10월에 수확한 송이버섯은 토굴을 만들어 보관하면서 소금에 절여둔다.\n2) ...
#
#                                                  ingredients
# item       [{'ingredientSeq': '1', 'ingredientNm': '송이버섯'...
# numOfRows  [{'ingredientSeq': '1', 'ingredientNm': '송이버섯'...
# pageNo                                                     1
# totCnt                                                     3
#
# [4 rows x 23 columns]

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국식품연구원_전통식품정보 서비스

#대표식품별 건강기능(병증처방) 정보

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

tradFoodCd = '103726' #전통식품코드

url = 'http://apis.data.go.kr/B551553/TradFoodInfoService/getFoodDiseaseList?serviceKey={}&type=json&tradFoodCd={}'.format(serviceKey, tradFoodCd)

response = requests.get(url, verify=False)

r_data = json.loads(response.text)

raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])
raw_data
# Out:
#    foodCd foodNm tradFoodCd tradFoodNm diseaseMasterSeq diseaseNmOri  \
# 0  100957   당귀뿌리     103726   당귀뿌리 저장법            38534         接藥入腎
# 1  100957   당귀뿌리     103726   당귀뿌리 저장법            39161        補腎中陽氣
#
#   diseaseNmKr diseaseNmDiff diseaseNmDiffKr diseaseModern  \
# 0        접약입신
# 1      보신중지양기           補腎陽             보신양
#
#                                          diseaseDocs  \
# 0  {'diseaseDoc': [{'docNm': '東醫寶鑑', 'docNmKr': '...
# 1  {'diseaseDoc': [{'docNm': '東醫寶鑑', 'docNmKr': '...
#
#                                        prescriptions
# 0  {'prescription': [{'prescriptionNmOri': '鹽', '...
# 1  {'prescription': [{'prescriptionNmOri': '鹽', '...

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국식품연구원_전통식품정보 서비스

#대표식품별 건강기능(학술) 정보

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

foodCd = '100424' #식품코드

url = 'http://apis.data.go.kr/B551553/TradFoodInfoService/getFoodHealthScholarList?serviceKey={}&type=json&foodCd={}'.format(serviceKey, foodCd)

response = requests.get(url, verify=False)

r_data = json.loads(response.text)

raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])
raw_data
# Out:
#    foodCd foodNm institutionsNm                       journalNm  \
# 0  100424     곶감      동아시아식생활학회                      동아시아식생활학회지
# 1  100424     곶감      한국식품영양과학회             한국식품영양과학회 산업심포지움발표집
# 2  100424     곶감      한국식품영양과학회                      한국식품영양과학회지
# 3  100424     곶감      한국식품영양과학회                      한국식품영양과학회지
# 4  100424     곶감      한국식품영양과학회                      한국식품영양과학회지
# 5  100424     곶감     한국식품저장유통학회  한국식품저장유통학회지 춘계총회 및 제 20차 학술발표회
# 6  100424     곶감       한국약용작물학회                한국약용작물학회 춘계학술발표회
#
#               vol  year                            articleNm    author  \
# 0           24(5)  2014                곶감 첨가량을 달리한 양갱의 품질 특성  봉준호 외 2명
# 1  Vol.2006 No.10  2006            산지별 곶감 메탄올 추출물의 항산화활성능 비교  임현애 외 7명
# 2           33(1)  2004               전국 유명산지별 전통곶감의 품질특성 비교  김종국 외 6명
# 3           33(2)  2004            상주 전통곶감의 제조과정 중 이화학적 품질특성   강우원 외6명
# 4           37(8)  2008             곶감, 생감 및 감잎 추출물의 생리활성 효과   홍정희 외3명
# 5                  2002                        곶감의 고품질화 기술개발       오상룡
# 6                  2011  프로폴리스 및 한약재를 이용한 기능성 곶감 개발 및 기능성 평가  박재성 외 3명
#
#   pageStart pageEnd                                            content etc
# 0               671  건시인 곶감은 기후가 따뜻하고 습기가 많으면 과육이 허물어 내리며 감의 폴리페놀 물...
# 1               322  곶감은 전통적으로 각혈이나 하혈과 같은 질환뿐만 아니라 기침, 딸국질, 숙취에 효능...
# 2               145  감의 주성분은 당질로서 함량이 15~16%인데 포도당과 과당의 함유량이 많으며, 단...
# 3               391  한방에서는 성숙과의 감꼭지는 딸국질․구토․야뇨증에, 곶감은 해소․토혈․객혈․이질 등...
# 4               964  떫은 감을 박피한 후 건조하여 제조하는 곶감은 오래전부터 우리나라에서 이용되고 있는...
# 5                47  감은 예로부터 화상, 동상, 해독 및 지혈 등의 치료에 널리 이용되어져 왔으며 특히...
# 6               399  곶감의 활성에는 항균, 항산화, 항종양작용 및 중금속 제거능과 같은 생리활성 및 당...

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국식품연구원_전통식품정보 서비스

#대표식품별 건강기능(한의문헌) 정보

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

foodCd = '100424' #식품코드

url = 'http://apis.data.go.kr/B551553/TradFoodInfoService/getFoodHealthOriMediList?serviceKey={}&type=json&foodCd={}'.format(serviceKey, foodCd)

response = requests.get(url, verify=False)

r_data = json.loads(response.text)

raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])
raw_data
# Out:
#    foodCd foodNm institutionsNm journalNm                        vol  year  \
# 0  100424     곶감       한국한의학연구원   한의학고전DB     別抄單方 > 單方 > 胃腑單方 凡二十七種  1927
# 1  100424     곶감       한국한의학연구원   한의학고전DB     別抄單方 > 單方 > 脾臟單方 凡二十四種  1927
# 2  100424     곶감       한국한의학연구원   한의학고전DB             卷之中 > 女科 > 痘疹門  1928
# 3  100424     곶감       한국한의학연구원   한의학고전DB           四醫經驗方 > 咽喉部 > 失音    미상
# 4  100424     곶감       한국한의학연구원   한의학고전DB        四醫經驗方 > 姙娠雜病 > 產後諸症    미상
# 5  100424     곶감       한국한의학연구원   한의학고전DB  增注類證活人書 卷二十一 > 小兒瘡疹 > 通聖散  1118
# 6  100424     곶감       한국한의학연구원   한의학고전DB              壽世祕訣 卷之一 > 嘔吐  1929
# 7  100424     곶감       한국한의학연구원   한의학고전DB               壽世祕訣 卷之一 > 血  1929
# 8  100424     곶감       한국한의학연구원   한의학고전DB         宜彙 卷之一 > 泄瀉 > 泄瀉腎泄  1871
# 9  100424     곶감       한국한의학연구원   한의학고전DB           宜彙 卷之一 > 痢疾 > 痢疾  1871
#
#           articleNm                               author pageStart pageEnd  \
# 0        별초단방(別抄單方)                              미상 (未詳)
# 1        별초단방(別抄單方)                              미상 (未詳)
# 2        양무신편(兩無神編)                            남재철 (南載喆)
# 3      사의경험방(四醫經驗方)  이석간, 채득기, 박렴, 허임 (李碩幹, 蔡得己, 朴濂, 許任)
# 4      사의경험방(四醫經驗方)  이석간, 채득기, 박렴, 허임 (李碩幹, 蔡得己, 朴濂, 許任)
# 5  증주유증활인서(增注類證活人書)                              주굉 (朱肱)
# 6        수세비결(壽世祕訣)                            이창우 (李昌雨)
# 7        수세비결(壽世祕訣)                            이창우 (李昌雨)
# 8            의휘(宜彙)                          금리산인 (錦里散人)
# 9            의휘(宜彙)                          금리산인 (錦里散人)
#
#                                              content  \
# 0  乾柿開胃厚腸胃, 可常食之. \n건시(乾柿, 곶감)는 위를 열고 장위(腸胃)를 두텁게...
# 1  乾杮健脾氣, 和酥蜜煎食, 主脾虛薄, 食不消化. 《本草》 \n건시(乾柿, 곶감)는 비...
# 2  痘瘡入目, 生翳障, 用白菊花 穀精草 綠豆 等分, 爲末. 每用一錢, 以乾柿餠一枚, 粟...
# 3  肺兪十五, 尺澤. 〈蔡〉 魚際. 〈朴〉 蜜水一椀飮. 槐花新瓦上炒熟, 懷之隨處細嚼, ...
# 4  咳逆, 壁鏡窠三五介, 煎取汁, 熱呷. 〈東〉 靑橘皮爲末 葱白, 童便煎服. 乾柿一介,...
# 5  右搗羅爲末, 每服用一大盞乾柿一箇. 生粟米泔一盞, 共一處, 煎候米泔盡, 只將乾柿去核喫...
# 6  凡反胃病, 乾杮同乾飯, 日日食, 遂癒. \n모든 반위병(反胃病)은 건시(乾杮, 곶감...
# 7  臟毒下血, 烏犀散. 淡豆豉十文, 大蒜二枚煨, 同擣丸梧子大, 煎香菜湯服二十丸, 日二服...
# 8  ○泄瀉, 乾柿或水柿, 多食, 卽效. 南某平生患腎泄症, 服紅柿, 卽止. ●米泔第二洗水...
# 9  痢疾, 乾柿眞油炒食, 神效. 冷痢痛泄好, 小兒尤好. 〈舟〉 ○桃實煎水, 和生淸服. ...
#
#                                   etc
# 0                                  단권
# 1                                  단권
# 2                 3卷1冊 ; 24.6×16.9 cm
# 3  不分卷 1冊/ 半葉框廓 上下內向雙葉花紋魚尾 /10行 小字30字
# 4  不分卷 1冊/ 半葉框廓 上下內向雙葉花紋魚尾 /10行 小字30字
# 5                                 22권
# 6         137張；22.7×15.6 cm , 15行 48字
# 7         137張；22.7×15.6 cm , 15行 48字
# 8                               5권 5책
# 9                               5권 5책

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국식품연구원_전통식품정보 서비스

#대표식품별 지역 정보

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

foodCd = '100424' #식품코드

url = 'http://apis.data.go.kr/B551553/TradFoodInfoService/getFoodAreaList?serviceKey={}&type=json&foodCd={}'.format(serviceKey, foodCd)

response = requests.get(url, verify=False)

r_data = json.loads(response.text)

raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])
raw_data
# Out:
#    foodCd foodNm institutionsNm                       journalNm    vol  year  \
# 0  100424     곶감        한국식품과학회                       한국식품과학학회지  47(1)  2015
# 1  100424     곶감     한국식품저장유통학회  한국식품저장유통학회지 춘계총회 및 제 20차 학술발표회         2002
#
#                                        articleNm   author pageStart pageEnd  \
# 0  FT-IR 스펙트럼 데이터의 다변량 통계분석을 이용한 곶감의 원산지 및 품종 식별  허설혜 외2명                26
# 1                                  곶감의 고품질화 기술개발      오상룡                47
#
#                                              content etc  \
# 0  우리나라에서는 주로 경북 상주, 청도, 경남 함안, 충북영동, 전북 완주가 대표적인...
# 1  감 과실(Diospyros kaki folium)은 아열대로부터 온대에 이르는 넓은...
#
#                            gubun
# 0  경북 상주, 청도, 경남 함안, 충북영동, 전북 완주
# 1                       영남지방, 상주

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국식품연구원_전통식품정보 서비스

#대표식품별 역사 정보

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

foodCd = '100424' #식품코드

url = 'http://apis.data.go.kr/B551553/TradFoodInfoService/getFoodHistoryList?serviceKey={}&type=json&foodCd={}'.format(serviceKey, foodCd)

response = requests.get(url, verify=False)

r_data = json.loads(response.text)

raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])
raw_data
# Out:
#    foodCd foodNm institutionsNm                       journalNm         vol  \
# 0  100424     곶감      서울대학교 규장각                   임원십육지 (林園十六志)           1
# 1  100424     곶감        한국고전번역원                        한국고전종합DB  가림보초(嘉林報草)
# 2  100424     곶감     한국식품저장유통학회  한국식품저장유통학회지 춘계총회 및 제 20차 학술발표회
#
#         year      articleNm       author pageStart               pageEnd  \
# 0     1835년경       시건방(柿乾方)     서유구(徐有榘)
# 1  2012~2015     각사등록(各司謄錄)  임천 군수(林川郡守)            8월 초4일 수영(水營)에 올린 보고
# 2       2002  곶감의 고품질화 기술개발          오상룡                              47
#
#                                              content etc gubun
# 0  큰 감을 껍질을 벗기고 납작하게 눌러 낮에는 햇볕을 쬐고 밤에는 이슬을 맞혀 다 마...        유래
# 1  ...捉)했습니다. 그러나 본사(本寺)는 어공(御供) 준시(蹲柹 곶감을 꼬챙이에 꿰...        유래
# 2  감 과실(Diospyros kaki folium)은 아열대로부터 온대에 이르는 넓은...        유래

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

#한국식품연구원_전통식품정보 서비스

#대표식품별 문화 정보

warnings.filterwarnings('ignore')

serviceKey ='%2BgRVEG2sLcCY1J7AoaObGxBO0MjarYlI%2BEj9fdydsxoG65eVtPCqxSyMwykxCYyFgqLVqKMplf7Ekl5kB5YjaA%3D%3D'

foodCd = '100424' #식품코드

url = 'http://apis.data.go.kr/B551553/TradFoodInfoService/getFoodCultureList?serviceKey={}&type=json&foodCd={}'.format(serviceKey, foodCd)

response = requests.get(url, verify=False)

r_data = json.loads(response.text)

raw_data = pd.DataFrame(r_data['response']['body']['items']['item'])
raw_data
# Out:
#    foodCd foodNm institutionsNm   journalNm         vol       year  \
# 0  100424     곶감        한국고전번역원    한국고전종합DB  계곡선생집 제25권  1994~1997
# 1  100424     곶감        한국고전번역원    한국고전종합DB    구사당집 제2권  2013~2015
# 2  100424     곶감      한국식품영양과학회  한국식품영양과학회지       33(1)       2004
#
#                 articleNm    author pageStart  \
# 0                계곡집(谿谷集)    장유(張維)
# 1              구사당집(九思堂集)  김낙행(金樂行)
# 2  전국 유명산지별 전통곶감의 품질특성 비교  김종국 외 6명
#
#                                      pageEnd  \
# 0                         일찍 죽은 아이들을 애도함[悼夭]
# 1  이백실 동영 께 답함 무오년(1738, 영조14) 〔答李伯實 東英 ○戊午〕
# 2                                        145
#
#                                              content etc gubun
# 0  ...헝클어 놔 성도 냈었고 / 時嗔亂書帙 대추 곶감 달라고 졸라 애도 썼었지 / ...        풍습
# 1  ...없고, 곶감도 귀합니다. 매우 흔한 물건을 말씀드리자면, 과일로는 귤과 유자이...         시
# 2  감(Diospyros kaki Thunb)은 우리나라를 비롯하여 중국, 일본 등 온...       식생활
